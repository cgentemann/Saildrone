# %% [markdown]
# ## OceanEddies GeoServer Example WFS Queries
# Below are a few examples of how to use the WFS service of the OceanEddies Geoserver.
#
# WFS is an open standard by the OGC. This notebook is meant as a quick intro rather than a full featured demo. Full tutorial for WFS and all other OGC webservices can be found at http://cite.opengeospatial.org/pub/cite/files/edu/index.html
#
# WFS was implemented in several versions. The GeoServer supports all major versions.

# %% [markdown]
# ## Minimal demo
# Below is an example of how to connect to the WFS and get data in the GeoJSON format.
#
# The example data is plottet on a leaflet map.

# %%
import json
import requests

from ipyleaflet import Map, basemaps, GeoJSON, LayersControl

# %% [markdown]
# ### web requests using `requests`
#
# `requests` is a library for quering http/https service. We use it here to construct the query in a comprehensible manner.

# %%
wfs_base_url = "https://maps.geomar.de/geoserver/OceanEddies/wfs"
requested_layer = "OceanEddies:current_positions"
requests_parameters = {
                        'service': 'wfs',
                        'version': '1.0.0',
                        'request': 'getFeature',
                        'typename': requested_layer,
                        #The line below will filter the results on the server
                        #'CQL_FILTER': "type like 'WaveGlider'",  # OCG CQL filter
                        #'viewparams': "maxage:48",  # parameters for custom view on geoserver: set max age of position to 48h 
                        "outputformat": "application/json"
                      }
response = requests.get(wfs_base_url, params=requests_parameters)
print(f'use the following link for your query: {response.url}')
# Out:
# use the following link for your query: https://maps.geomar.de/geoserver/OceanEddies/wfs?service=wfs&version=1.0.0&request=getFeature&typename=OceanEddies%3Acurrent_positions&outputformat=application%2Fjson

# %% [markdown]
# ### Server side filtering
# WFS provides a couple of methods for filtering data on the server. The most simple one is `CQL_FILTER`. The basic
# principle is demonstrated below. In this case, we are filtering by the property `type`. `type` is the column that holds the device type (e.g. WaveGlider, OceanGlider, Drifter, ...) of a position. Other columns you
# might be interested in filtering for could be `display_name` or `shortname`. Look into the `properties` of the returned geojson, each property was generated by a DB column you can filter by.
#
# Scroll up again an uset the layer control widget after running the cell below.

# %%
requests_parameters = {
                        'service': 'wfs',
                        'version': '1.0.0',
                        'request': 'getFeature',
                        'typename': requested_layer,
                        #The line below will filter the results on the server
                       # 'CQL_FILTER': "type like 'WaveGlider'",  
                        "outputformat": "application/json"
                      }
response = requests.get(wfs_base_url, params=requests_parameters)
print(f'use the following link for your query: {response.url}')
wg_positions = GeoJSON(data=response.json(), hover_style={'fillColor': 'red'}, name='WaveGlider Positions') 
print(response.json())
# Out:
# use the following link for your query: https://maps.geomar.de/geoserver/OceanEddies/wfs?service=wfs&version=1.0.0&request=getFeature&typename=OceanEddies%3Acurrent_positions&outputformat=application%2Fjson
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'id': 'current_positions.fid--1353068_16eb8b7b08d_-7400', 'geometry': {'type': 'Point', 'coordinates': [-24.45222, 14.47993]}, 'geometry_name': 'geom', 'properties': {'shortname': 'WG_GMR2', 'display_name': 'WG2', 'name': 'WaveGlider GEOMAR2', 'sensor_home': 'GEOMAR', 'type': 'WaveGlider', 'awi_urn': 'vehicle:glider_gmr_wg2', 'surveydata_offering': None, 'obs_timestamp': '2019-11-29T20:16:15Z', 'obs_age': '-00:09:00', 'heading': 83, 'speed_over_ground': 1.524298, 'additional_data': '', 'platform_id': 1}}, {'type': 'Feature', 'id': 'current_positions.fid--1353068_16eb8b7b08d_-73ff', 'geometry': {'type': 'Point', 'coordinates': [-21.68145, 17.99558]}, 'geometry_name': 'geom', 'properties': {'shortname': 'WG_GMR4', 'display_name': 'WG4', 'name': 'WaveGlider GEOMAR4', 'sensor_home': 'GEOMAR', 'type': 'WaveGlider', 'awi_urn': 'vehicle:glider_gmr_wg4', 'surveydata_offering': None, 'obs_timestamp': '2019-11-29T20:11:09Z', 'obs_age': '-00:14:00', 'heading': 89, 'speed_over_ground': 1.273218, 'additional_data': '', 'platform_id': 2}}, {'type': 'Feature', 'id': 'current_positions.fid--1353068_16eb8b7b08d_-73fe', 'geometry': {'type': 'Point', 'coordinates': [-23.87798406, 14.470614]}, 'geometry_name': 'geom', 'properties': {'shortname': 'OG_IFM09', 'display_name': 'OG09', 'name': 'OceanGlider IFM09', 'sensor_home': 'GEOMAR', 'type': 'OceanGlider', 'awi_urn': 'vehicle:glider_gmr_ifm09', 'surveydata_offering': None, 'obs_timestamp': '2019-11-29T20:20:20Z', 'obs_age': '-00:05:00', 'heading': 98, 'speed_over_ground': None, 'additional_data': 'depth: 95.43308926777206,age: 2410.2851238250732', 'platform_id': 5}}, {'type': 'Feature', 'id': 'current_positions.fid--1353068_16eb8b7b08d_-73fd', 'geometry': {'type': 'Point', 'coordinates': [-24.60300524, 14.52477489]}, 'geometry_name': 'geom', 'properties': {'shortname': 'OG_IFM12', 'display_name': 'OG12', 'name': 'OceanGlider IFM12', 'sensor_home': 'GEOMAR', 'type': 'OceanGlider', 'awi_urn': 'vehicle:glider_gmr_ifm12', 'surveydata_offering': None, 'obs_timestamp': '2019-11-29T20:20:20Z', 'obs_age': '-00:05:00', 'heading': 86, 'speed_over_ground': None, 'additional_data': 'depth: 961.5010742764819,age: 16630.218000888824', 'platform_id': 6}}, {'type': 'Feature', 'id': 'current_positions.fid--1353068_16eb8b7b08d_-73fc', 'geometry': {'type': 'Point', 'coordinates': [-21.90264267, 17.88212197]}, 'geometry_name': 'geom', 'properties': {'shortname': 'OG_IFM14', 'display_name': 'OG14', 'name': 'OceanGlider IFM14', 'sensor_home': 'GEOMAR', 'type': 'OceanGlider', 'awi_urn': 'vehicle:glider_gmr_ifm14', 'surveydata_offering': None, 'obs_timestamp': '2019-11-29T20:20:20Z', 'obs_age': '-00:05:00', 'heading': 315, 'speed_over_ground': None, 'additional_data': 'depth: 538.9995453802915,age: 8950.159004926682', 'platform_id': 8}}, {'type': 'Feature', 'id': 'current_positions.fid--1353068_16eb8b7b08d_-73fb', 'geometry': {'type': 'Point', 'coordinates': [-25.46041469, 14.29169298]}, 'geometry_name': 'geom', 'properties': {'shortname': 'OG_Sebastian', 'display_name': 'OGS', 'name': 'OceanGlider Sebastian', 'sensor_home': 'HZG', 'type': 'OceanGlider', 'awi_urn': None, 'surveydata_offering': 'sebastian', 'obs_timestamp': '2019-11-29T20:20:20Z', 'obs_age': '-00:05:00', 'heading': 92, 'speed_over_ground': None, 'additional_data': 'depth: 44.71677836674559,age: 11050.051087617874', 'platform_id': 11}}, {'type': 'Feature', 'id': 'current_positions.fid--1353068_16eb8b7b08d_-73fa', 'geometry': {'type': 'Point', 'coordinates': [-23.8510434, 14.5073115]}, 'geometry_name': 'geom', 'properties': {'shortname': 'OG_Comet', 'display_name': 'OGC', 'name': 'OceanGlider Comet', 'sensor_home': 'HZG', 'type': 'OceanGlider', 'awi_urn': None, 'surveydata_offering': 'comet', 'obs_timestamp': '2019-11-29T20:20:20Z', 'obs_age': '-00:05:00', 'heading': 275, 'speed_over_ground': None, 'additional_data': 'depth: 449.6904544771822,age: 22750.33568906784', 'platform_id': 12}}, {'type ...

# %% [markdown]
# ## assign the web response to dict_assets  (a dictionary containing all the assets)

# %%
dict_assets = response.json()
dict_assets
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-7400',
#    'geometry': {'type': 'Point', 'coordinates': [-24.45222, 14.47993]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'WG_GMR2',
#     'display_name': 'WG2',
#     'name': 'WaveGlider GEOMAR2',
#     'sensor_home': 'GEOMAR',
#     'type': 'WaveGlider',
#     'awi_urn': 'vehicle:glider_gmr_wg2',
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-29T20:16:15Z',
#     'obs_age': '-00:09:00',
#     'heading': 83,
#     'speed_over_ground': 1.524298,
#     'additional_data': '',
#     'platform_id': 1}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73ff',
#    'geometry': {'type': 'Point', 'coordinates': [-21.68145, 17.99558]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'WG_GMR4',
#     'display_name': 'WG4',
#     'name': 'WaveGlider GEOMAR4',
#     'sensor_home': 'GEOMAR',
#     'type': 'WaveGlider',
#     'awi_urn': 'vehicle:glider_gmr_wg4',
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-29T20:11:09Z',
#     'obs_age': '-00:14:00',
#     'heading': 89,
#     'speed_over_ground': 1.273218,
#     'additional_data': '',
#     'platform_id': 2}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73fe',
#    'geometry': {'type': 'Point', 'coordinates': [-23.87798406, 14.470614]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'OG_IFM09',
#     'display_name': 'OG09',
#     'name': 'OceanGlider IFM09',
#     'sensor_home': 'GEOMAR',
#     'type': 'OceanGlider',
#     'awi_urn': 'vehicle:glider_gmr_ifm09',
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-29T20:20:20Z',
#     'obs_age': '-00:05:00',
#     'heading': 98,
#     'speed_over_ground': None,
#     'additional_data': 'depth: 95.43308926777206,age: 2410.2851238250732',
#     'platform_id': 5}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73fd',
#    'geometry': {'type': 'Point', 'coordinates': [-24.60300524, 14.52477489]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'OG_IFM12',
#     'display_name': 'OG12',
#     'name': 'OceanGlider IFM12',
#     'sensor_home': 'GEOMAR',
#     'type': 'OceanGlider',
#     'awi_urn': 'vehicle:glider_gmr_ifm12',
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-29T20:20:20Z',
#     'obs_age': '-00:05:00',
#     'heading': 86,
#     'speed_over_ground': None,
#     'additional_data': 'depth: 961.5010742764819,age: 16630.218000888824',
#     'platform_id': 6}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73fc',
#    'geometry': {'type': 'Point', 'coordinates': [-21.90264267, 17.88212197]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'OG_IFM14',
#     'display_name': 'OG14',
#     'name': 'OceanGlider IFM14',
#     'sensor_home': 'GEOMAR',
#     'type': 'OceanGlider',
#     'awi_urn': 'vehicle:glider_gmr_ifm14',
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-29T20:20:20Z',
#     'obs_age': '-00:05:00',
#     'heading': 315,
#     'speed_over_ground': None,
#     'additional_data': 'depth: 538.9995453802915,age: 8950.159004926682',
#     'platform_id': 8}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73fb',
#    'geometry': {'type': 'Point', 'coordinates': [-25.46041469, 14.29169298]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'OG_Sebastian',
#     'display_name': 'OGS',
#     'name': 'OceanGlider Sebastian',
#     'sensor_home': 'HZG',
#     'type': 'OceanGlider',
#     'awi_urn': None,
#     'surveydata_offering': 'sebastian',
#     'obs_timestamp': '2019-11-29T20:20:20Z',
#     'obs_age': '-00:05:00',
#     'heading': 92,
#     'speed_over_ground': None,
#     'additional_data': 'depth: 44.71677836674559,age: 11050.051087617874',
#     'platform_id': 11}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73fa',
#    'geometry': {'type': 'Point', 'coordinates': [-23.8510434, 14.5073115]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'OG_Comet',
#     'display_name': 'OGC',
#     'name': 'OceanGlider Comet',
#     'sensor_home': 'HZG',
#     'type': 'OceanGlider',
#     'awi_urn': None,
#     'surveydata_offering': 'comet',
#     'obs_timestamp': '2019-11-29T20:20:20Z',
#     'obs_age': '-00:05:00',
#     'heading': 275,
#     'speed_over_ground': None,
#     'additional_data': 'depth: 449.6904544771822,age: 22750.33568906784',
#     'platform_id': 12}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73f9',
#    'geometry': {'type': 'Point', 'coordinates': [-20.319147, 17.360192]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'M',
#     'display_name': 'MET',
#     'name': 'Meteor',
#     'sensor_home': 'Uni HH',
#     'type': 'Ship',
#     'awi_urn': None,
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-29T19:53:08Z',
#     'obs_age': '-00:32:00',
#     'heading': 218,
#     'speed_over_ground': 11.8,
#     'additional_data': '',
#     'platform_id': 14}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73f8',
#    'geometry': {'type': 'Point', 'coordinates': [-20.5524704, 18.4648544]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'SD-1030',
#     'display_name': 'SD1',
#     'name': 'Saildrone SD-1030',
#     'sensor_home': 'GEOMAR',
#     'type': 'Saildrone',
#     'awi_urn': None,
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-29T20:24:11Z',
#     'obs_age': '-00:01:00',
#     'heading': None,
#     'speed_over_ground': None,
#     'additional_data': '',
#     'platform_id': 19}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73f7',
#    'geometry': {'type': 'Point', 'coordinates': [-20.5152176, 18.0708528]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'SD-1053',
#     'display_name': 'SD2',
#     'name': 'Saildrone SD-1053',
#     'sensor_home': 'GEOMAR',
#     'type': 'Saildrone',
#     'awi_urn': None,
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-29T20:14:59Z',
#     'obs_age': '-00:10:00',
#     'heading': 318,
#     'speed_over_ground': None,
#     'additional_data': '',
#     'platform_id': 20}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73f6',
#    'geometry': {'type': 'Point', 'coordinates': [-22.89807222, 16.60033889]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'ground_station_sal',
#     'display_name': 'GS',
#     'name': 'Cabo Verde Sal Ground Station',
#     'sensor_home': 'HZG',
#     'type': 'GroundStation',
#     'awi_urn': None,
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-29T20:03:03.355Z',
#     'obs_age': '-00:22:00',
#     'heading': 0,
#     'speed_over_ground': None,
#     'additional_data': '',
#     'platform_id': 27}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73f5',
#    'geometry': {'type': 'Point', 'coordinates': [-22.9331595, 18.60906319]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'OG_IFM08',
#     'display_name': 'OG08',
#     'name': 'OceanGlider IFM08',
#     'sensor_home': 'GEOMAR',
#     'type': 'OceanGlider',
#     'awi_urn': 'vehicle:glider_gmr_ifm08',
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-29T20:20:20Z',
#     'obs_age': '-00:05:00',
#     'heading': 163,
#     'speed_over_ground': None,
#     'additional_data': 'depth: 82.59651996496446,age: 4930.108953237534',
#     'platform_id': 28}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73f4',
#    'geometry': {'type': 'Point', 'coordinates': [-24.252, 17.608]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'MO_001',
#     'display_name': 'MO1',
#     'name': 'CVOO Mooring',
#     'sensor_home': 'GEOMAR',
#     'type': 'Mooring',
#     'awi_urn': None,
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-29T10:10:50Z',
#     'obs_age': '-10:14:00',
#     'heading': 112,
#     'speed_over_ground': None,
#     'additional_data': '',
#     'platform_id': 29}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73f3',
#    'geometry': {'type': 'Point', 'coordinates': [-23.604, 14.5618]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'SVP_009',
#     'display_name': 'SVP09',
#     'name': 'SVP Drifter 9',
#     'sensor_home': 'GEOMAR',
#     'type': 'Drifter',
#     'awi_urn': 'drifter:drifter_gmr_svp_009',
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-29T18:00:00Z',
#     'obs_age': '-02:25:00',
#     'heading': 135,
#     'speed_over_ground': None,
#     'additional_data': '',
#     'platform_id': 428}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16eb8b7b08d_-73f2',
#    'geometry': {'type': 'Point', 'coordinates': [-24.9558, 14.7174]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'SVP_011',
#     'display_name': 'SVP11',
#     'name': 'SVP Drifter 11',
#     'sensor_home': 'GEOMAR',
#     'type': 'Drifter',
#     'awi_urn': 'drifter:drifter_gmr_svp_011',
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-29T18:00:00Z',
#     'obs_age': '-02:25:00',
#     'heading': 309,
#     'speed_over_ground': None,
#     'additional_data': '',
#     'platform_id': 430}}],
#  'totalFeatures': 15,
#  'numberMatched': 15,
#  'numberReturned': 15,
#  'timeStamp': '2019-11-29T20:25:20.776Z',
#  'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}}

# %% [markdown]
# ## showing you how to extract data from the dictionary.  This is for the first [0] feature, you will need to loop over and extract data from all the features and save into a xarray dataset
#
# Basically the information needed for this is: unique identifier for the "vessel" -- e.g. MMSI, or some ID that we can generate together for things that do not already have an MMSI.  for this I think you should use the 'name'
# type of vessel
# Latitude -- decimal degrees
# Longitude -- decimal degrees
# Timestamp -- in unix timestamp

# %%
dict_assets['features'][0]['geometry']
# Out:
# {'type': 'Point', 'coordinates': [-24.45222, 14.47993]}

# %%
dict_assets['features'][0]['properties']['type']
# Out:
# 'WaveGlider'

# %% [markdown]
# ## get the total number of assets

# %%
number_of_assets = len(dict_assets['features'])
print(number_of_assets)
# Out:
# 15

# %% [markdown]
# ## check out what properties there are to query

# %%
dict_assets['features'][i]['properties']
# Out:
# {'shortname': 'SVP_011',
#  'display_name': 'SVP11',
#  'name': 'SVP Drifter 11',
#  'sensor_home': 'GEOMAR',
#  'type': 'Drifter',
#  'awi_urn': 'drifter:drifter_gmr_svp_011',
#  'surveydata_offering': None,
#  'obs_timestamp': '2019-11-29T18:00:00Z',
#  'obs_age': '-02:25:00',
#  'heading': 309,
#  'speed_over_ground': None,
#  'additional_data': '',
#  'platform_id': 430}

# %% [markdown]
# ## check out what features there are to query

# %%
dict_assets['features'][i]
# Out:
# {'type': 'Feature',
#  'id': 'current_positions.fid--1353068_16eb8b7b08d_-73f2',
#  'geometry': {'type': 'Point', 'coordinates': [-24.9558, 14.7174]},
#  'geometry_name': 'geom',
#  'properties': {'shortname': 'SVP_011',
#   'display_name': 'SVP11',
#   'name': 'SVP Drifter 11',
#   'sensor_home': 'GEOMAR',
#   'type': 'Drifter',
#   'awi_urn': 'drifter:drifter_gmr_svp_011',
#   'surveydata_offering': None,
#   'obs_timestamp': '2019-11-29T18:00:00Z',
#   'obs_age': '-02:25:00',
#   'heading': 309,
#   'speed_over_ground': None,
#   'additional_data': '',
#   'platform_id': 430}}

# %% [markdown]
# ## loop over each assets and get the following infomation:
# type, platform_id,
# in geometry feature you want to get the coordinates (lat/lon)

# %%
#to print the type 
print(dict_assets['features'][0]['properties']['type'])  #type
print(dict_assets['features'][1]['properties']['type'])  #type
print(dict_assets['features'][2]['properties']['type'])  #type
# Out:
# WaveGlider
# WaveGlider
# OceanGlider

# %% [markdown]
# ## Now loop over the number of assets and print the different properties you want

# %%
# Out:
# WaveGlider
# WaveGlider
# OceanGlider
# OceanGlider
# OceanGlider
# OceanGlider
# OceanGlider
# Ship
# Saildrone
# Saildrone
# GroundStation
# OceanGlider
# Mooring
# Drifter
# Drifter
