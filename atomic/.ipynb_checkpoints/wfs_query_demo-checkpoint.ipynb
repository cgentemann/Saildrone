# %% [markdown]
# ## OceanEddies GeoServer Example WFS Queries
# Below are a few examples of how to use the WFS service of the OceanEddies Geoserver.
#
# WFS is an open standard by the OGC. This notebook is meant as a quick intro rather than a full featured demo. Full tutorial for WFS and all other OGC webservices can be found at http://cite.opengeospatial.org/pub/cite/files/edu/index.html
#
# WFS was implemented in several versions. The GeoServer supports all major versions.

# %% [markdown]
# ## Minimal demo
# Below is an example of how to connect to the WFS and get data in the GeoJSON format.
#
# The example data is plottet on a leaflet map.

# %%
import json
import requests

from ipyleaflet import Map, basemaps, GeoJSON, LayersControl

# %% [markdown]
# ### web requests using `requests`
#
# `requests` is a library for quering http/https service. We use it here to construct the query in a comprehensible manner.

# %%
wfs_base_url = "https://maps.geomar.de/geoserver/OceanEddies/wfs"
requested_layer = "OceanEddies:current_positions"
requests_parameters = {
                        'service': 'wfs',
                        'version': '1.0.0',
                        'request': 'getFeature',
                        'typename': requested_layer,
                        #The line below will filter the results on the server
                        #'CQL_FILTER': "type like 'WaveGlider'",  # OCG CQL filter
                        #'viewparams': "maxage:48",  # parameters for custom view on geoserver: set max age of position to 48h 
                        "outputformat": "application/json"
                      }
response = requests.get(wfs_base_url, params=requests_parameters)
print(f'use the following link for your query: {response.url}')
# Out:
# use the following link for your query: https://maps.geomar.de/geoserver/OceanEddies/wfs?service=wfs&version=1.0.0&request=getFeature&typename=OceanEddies%3Acurrent_positions&outputformat=application%2Fjson

# %% [markdown]
# ### Server side filtering
# WFS provides a couple of methods for filtering data on the server. The most simple one is `CQL_FILTER`. The basic
# principle is demonstrated below. In this case, we are filtering by the property `type`. `type` is the column that holds the device type (e.g. WaveGlider, OceanGlider, Drifter, ...) of a position. Other columns you
# might be interested in filtering for could be `display_name` or `shortname`. Look into the `properties` of the returned geojson, each property was generated by a DB column you can filter by.
#
# Scroll up again an uset the layer control widget after running the cell below.

# %%
requests_parameters = {
                        'service': 'wfs',
                        'version': '1.0.0',
                        'request': 'getFeature',
                        'typename': requested_layer,
                        #The line below will filter the results on the server
                       # 'CQL_FILTER': "type like 'WaveGlider'",  
                        "outputformat": "application/json"
                      }
response = requests.get(wfs_base_url, params=requests_parameters)
print(f'use the following link for your query: {response.url}')
wg_positions = GeoJSON(data=response.json(), hover_style={'fillColor': 'red'}, name='WaveGlider Positions') 
print(response.json())
# Out:
# use the following link for your query: https://maps.geomar.de/geoserver/OceanEddies/wfs?service=wfs&version=1.0.0&request=getFeature&typename=OceanEddies%3Acurrent_positions&outputformat=application%2Fjson
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'id': 'current_positions.fid--1353068_16e83342c45_f0', 'geometry': {'type': 'Point', 'coordinates': [-24.99518, 16.87767]}, 'geometry_name': 'geom', 'properties': {'shortname': 'WG_GMR2', 'display_name': 'WG2', 'name': 'WaveGlider GEOMAR2', 'sensor_home': 'GEOMAR', 'type': 'WaveGlider', 'awi_urn': 'vehicle:glider_gmr_wg2', 'surveydata_offering': None, 'obs_timestamp': '2019-11-19T16:35:10Z', 'obs_age': '-08:32:00', 'heading': 14, 'speed_over_ground': 0.9859610000000001, 'additional_data': None, 'platform_id': 1}}, {'type': 'Feature', 'id': 'current_positions.fid--1353068_16e83342c45_f1', 'geometry': {'type': 'Point', 'coordinates': [-23.50007, 18.51849]}, 'geometry_name': 'geom', 'properties': {'shortname': 'WG_GMR4', 'display_name': 'WG4', 'name': 'Wave Glider GEOMAR4', 'sensor_home': 'GEOMAR', 'type': 'WaveGlider', 'awi_urn': 'vehicle:glider_gmr_wg4', 'surveydata_offering': None, 'obs_timestamp': '2019-11-20T00:53:30Z', 'obs_age': '-00:14:00', 'heading': 0, 'speed_over_ground': 1.448164, 'additional_data': None, 'platform_id': 2}}, {'type': 'Feature', 'id': 'current_positions.fid--1353068_16e83342c45_f2', 'geometry': {'type': 'Point', 'coordinates': [-21.2116, 17.5798]}, 'geometry_name': 'geom', 'properties': {'shortname': 'OG_IFM14', 'display_name': 'OG14', 'name': 'OceanGlider IFM14', 'sensor_home': 'GEOMAR', 'type': 'OceanGlider', 'awi_urn': 'vehicle:glider_gmr_ifm14', 'surveydata_offering': None, 'obs_timestamp': '2019-11-19T20:11:52Z', 'obs_age': '-04:56:00', 'heading': 229, 'speed_over_ground': None, 'additional_data': None, 'platform_id': 8}}, {'type': 'Feature', 'id': 'current_positions.fid--1353068_16e83342c45_f3', 'geometry': {'type': 'Point', 'coordinates': [-24.248825, 17.58374]}, 'geometry_name': 'geom', 'properties': {'shortname': 'M', 'display_name': 'MET', 'name': 'Meteor', 'sensor_home': 'Uni HH', 'type': 'Ship', 'awi_urn': None, 'surveydata_offering': None, 'obs_timestamp': '2019-11-20T00:04:19Z', 'obs_age': '-01:03:00', 'heading': 32, 'speed_over_ground': 0.9, 'additional_data': None, 'platform_id': 14}}, {'type': 'Feature', 'id': 'current_positions.fid--1353068_16e83342c45_f4', 'geometry': {'type': 'Point', 'coordinates': [-23.1753184, 18.7562416]}, 'geometry_name': 'geom', 'properties': {'shortname': 'SD-1030', 'display_name': 'SD1', 'name': 'Saildrone SD-1030', 'sensor_home': 'GEOMAR', 'type': 'Saildrone', 'awi_urn': None, 'surveydata_offering': None, 'obs_timestamp': '2019-11-20T01:02:04Z', 'obs_age': '-00:06:00', 'heading': 275, 'speed_over_ground': 2.174, 'additional_data': None, 'platform_id': 19}}, {'type': 'Feature', 'id': 'current_positions.fid--1353068_16e83342c45_f5', 'geometry': {'type': 'Point', 'coordinates': [-20.985376, 17.7072112]}, 'geometry_name': 'geom', 'properties': {'shortname': 'SD-1053', 'display_name': 'SD2', 'name': 'Saildrone SD-1053', 'sensor_home': 'GEOMAR', 'type': 'Saildrone', 'awi_urn': None, 'surveydata_offering': None, 'obs_timestamp': '2019-11-20T01:02:47Z', 'obs_age': '-00:05:00', 'heading': 270, 'speed_over_ground': None, 'additional_data': None, 'platform_id': 20}}, {'type': 'Feature', 'id': 'current_positions.fid--1353068_16e83342c45_f6', 'geometry': {'type': 'Point', 'coordinates': [-22.89807222, 16.60033889]}, 'geometry_name': 'geom', 'properties': {'shortname': 'ground_station_sal', 'display_name': 'GS', 'name': 'Cabo Verde Sal Ground Station', 'sensor_home': 'HZG', 'type': 'GroundStation', 'awi_urn': None, 'surveydata_offering': None, 'obs_timestamp': '2019-11-20T02:03:03.309Z', 'obs_age': '00:54:00', 'heading': 0, 'speed_over_ground': None, 'additional_data': None, 'platform_id': 27}}, {'type': 'Feature', 'id': 'current_positions.fid--1353068_16e83342c45_f7', 'geometry': {'type': 'Point', 'coordinates': [-24.1119, 18.7601]}, 'geometry_name': 'geom', 'properties': {'shortname': 'OG_IFM08', 'display_name': 'OG08', 'name': 'OceanGlider IFM08', 'sensor_home': 'GEOMAR', 'type': 'OceanGlider', 'awi_urn':  ...

# %% [markdown]
# ## assign the web response to dict_assets  (a dictionary containing all the assets)

# %%
dict_assets = response.json()
dict_assets
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16e83342c45_-9c',
#    'geometry': {'type': 'Point', 'coordinates': [-24.99518, 16.87767]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'WG_GMR2',
#     'display_name': 'WG2',
#     'name': 'WaveGlider GEOMAR2',
#     'sensor_home': 'GEOMAR',
#     'type': 'WaveGlider',
#     'awi_urn': 'vehicle:glider_gmr_wg2',
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-19T16:35:10Z',
#     'obs_age': '-08:22:00',
#     'heading': 14,
#     'speed_over_ground': 0.9859610000000001,
#     'additional_data': None,
#     'platform_id': 1}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16e83342c45_-9b',
#    'geometry': {'type': 'Point', 'coordinates': [-23.50007, 18.51849]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'WG_GMR4',
#     'display_name': 'WG4',
#     'name': 'Wave Glider GEOMAR4',
#     'sensor_home': 'GEOMAR',
#     'type': 'WaveGlider',
#     'awi_urn': 'vehicle:glider_gmr_wg4',
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-20T00:53:30Z',
#     'obs_age': '-00:04:00',
#     'heading': 0,
#     'speed_over_ground': 1.448164,
#     'additional_data': None,
#     'platform_id': 2}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16e83342c45_-9a',
#    'geometry': {'type': 'Point', 'coordinates': [-21.2116, 17.5798]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'OG_IFM14',
#     'display_name': 'OG14',
#     'name': 'OceanGlider IFM14',
#     'sensor_home': 'GEOMAR',
#     'type': 'OceanGlider',
#     'awi_urn': 'vehicle:glider_gmr_ifm14',
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-19T20:11:52Z',
#     'obs_age': '-04:45:00',
#     'heading': 229,
#     'speed_over_ground': None,
#     'additional_data': None,
#     'platform_id': 8}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16e83342c45_-99',
#    'geometry': {'type': 'Point', 'coordinates': [-24.248825, 17.58374]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'M',
#     'display_name': 'MET',
#     'name': 'Meteor',
#     'sensor_home': 'Uni HH',
#     'type': 'Ship',
#     'awi_urn': None,
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-20T00:04:19Z',
#     'obs_age': '-00:53:00',
#     'heading': 32,
#     'speed_over_ground': 0.9,
#     'additional_data': None,
#     'platform_id': 14}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16e83342c45_-98',
#    'geometry': {'type': 'Point', 'coordinates': [-23.1632352, 18.7555104]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'SD-1030',
#     'display_name': 'SD1',
#     'name': 'Saildrone SD-1030',
#     'sensor_home': 'GEOMAR',
#     'type': 'Saildrone',
#     'awi_urn': None,
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-20T00:52:03Z',
#     'obs_age': '-00:05:00',
#     'heading': 270,
#     'speed_over_ground': None,
#     'additional_data': None,
#     'platform_id': 19}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16e83342c45_-97',
#    'geometry': {'type': 'Point', 'coordinates': [-20.9791104, 17.7072208]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'SD-1053',
#     'display_name': 'SD2',
#     'name': 'Saildrone SD-1053',
#     'sensor_home': 'GEOMAR',
#     'type': 'Saildrone',
#     'awi_urn': None,
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-20T00:52:47Z',
#     'obs_age': '-00:04:00',
#     'heading': 270,
#     'speed_over_ground': None,
#     'additional_data': None,
#     'platform_id': 20}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16e83342c45_-96',
#    'geometry': {'type': 'Point', 'coordinates': [-22.89807222, 16.60033889]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'ground_station_sal',
#     'display_name': 'GS',
#     'name': 'Cabo Verde Sal Ground Station',
#     'sensor_home': 'HZG',
#     'type': 'GroundStation',
#     'awi_urn': None,
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-20T01:03:03.601Z',
#     'obs_age': '00:05:00',
#     'heading': 0,
#     'speed_over_ground': None,
#     'additional_data': None,
#     'platform_id': 27}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16e83342c45_-95',
#    'geometry': {'type': 'Point', 'coordinates': [-24.1119, 18.7601]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'OG_IFM08',
#     'display_name': 'OG08',
#     'name': 'OceanGlider IFM08',
#     'sensor_home': 'GEOMAR',
#     'type': 'OceanGlider',
#     'awi_urn': 'vehicle:glider_gmr_ifm08',
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-20T00:09:04Z',
#     'obs_age': '-00:48:00',
#     'heading': 100,
#     'speed_over_ground': None,
#     'additional_data': None,
#     'platform_id': 28}},
#   {'type': 'Feature',
#    'id': 'current_positions.fid--1353068_16e83342c45_-94',
#    'geometry': {'type': 'Point', 'coordinates': [-27.4638, 16.1836]},
#    'geometry_name': 'geom',
#    'properties': {'shortname': 'SVP_001',
#     'display_name': 'SVP01',
#     'name': 'SVP Drifter 1',
#     'sensor_home': 'GEOMAR',
#     'type': 'Drifter',
#     'awi_urn': None,
#     'surveydata_offering': None,
#     'obs_timestamp': '2019-11-20T00:00:00Z',
#     'obs_age': '-00:57:00',
#     'heading': 258,
#     'speed_over_ground': None,
#     'additional_data': None,
#     'platform_id': 420}}],
#  'totalFeatures': 9,
#  'numberMatched': 9,
#  'numberReturned': 9,
#  'timeStamp': '2019-11-20T00:57:40.444Z',
#  'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}}

# %% [markdown]
# ## showing you how to extract data from the dictionary.  This is for the first [0] feature, you will need to loop over and extract data from all the features and save into a xarray dataset
#
# Basically the information needed for this is: unique identifier for the "vessel" -- e.g. MMSI, or some ID that we can generate together for things that do not already have an MMSI.  for this I think you should use the 'name'
# type of vessel
# Latitude -- decimal degrees
# Longitude -- decimal degrees
# Timestamp -- in unix timestamp

# %%
dict_assets['features'][0]['geometry']
# Out:
# {'type': 'Point', 'coordinates': [-24.99518, 16.87767]}

# %%
dict_assets['features'][0]['properties']['type']
# Out:
# 'WaveGlider'
