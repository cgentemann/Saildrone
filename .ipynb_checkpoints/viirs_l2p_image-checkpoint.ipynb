# %%
# %matplotlib inline
from matplotlib import style
style.use('ggplot')
import numpy as np
import matplotlib.pyplot as plt
import numpy.ma as ma
from netCDF4 import Dataset, date2index, num2date
from palettable import colorbrewer
from datetime import datetime, timedelta
from bs4 import BeautifulSoup
import requests
def listFD(url, ext=''):
    page = requests.get(url).text
    #print(page)
    soup = BeautifulSoup(page, 'html.parser')
    return [url + node.get('href') for node in soup.find_all('a') if (node.get('href').endswith(ext) and node.get('href').startswith('2'))]

# %%
from os.path import exists

filename_viirs_proc = 'F:/data/cruise_data/saildrone/baja-2018/viirs_l2p_files.npy'
filename_viirs_sst = 'F:/data/cruise_data/saildrone/baja-2018/viirs_sst_l2p_data.npy'
filename_png = 'F:/data/cruise_data/saildrone/baja-2018/recent_viirs_sst_l2p_.png'

# %%
for incr_day in range(0,1):
    d = datetime.today() + timedelta(days=incr_day)
    day_of_year = d.timetuple().tm_yday

    url = 'https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/' \
            + str(d.year) + '/' + str(day_of_year).zfill(3) + '/'
    ext = 'nc'

    filenames=listFD(url, ext)
    ilen=len(filenames)
    for ic in range(1,ilen):
        file = filenames[ic]
        print(file)
        #save which files have been processed
        idyj=int(file[101:104])
        ihr=int(file[113:115])
        imin=int(file[115:117])
        print(idyj,ihr,imin)

        nc = Dataset(file)
        lat2 = nc.variables['lat'][:] #[2500:3250]
        nc.close()
        maxlat = np.ma.max(lat2)
        minlat = np.ma.min(lat2)

        ilat_check=0
        if minlat<40.0 and maxlat>40.0:
            ilat_check=1
        if minlat>25.0 and maxlat<40.0:
            ilat_check=1
        if minlat<25.0 and maxlat>25.0:
            ilat_check=1
        if ilat_check==0:
            continue  #no data at right latitude
            
        nc = Dataset(file)
        lon2 = nc.variables['lon'][:] #[2500:3250]
        nc.close()
        
        minlon = np.ma.min(lon2)
        print(maxlat,minlat)
        if minlon>0:
            continue

        minlon = np.ma.min(lon2[lon2<0])
        maxlon = np.ma.max(lon2[lon2<0])
        
        ilon_check=0
        if minlon<-130 and maxlon>-130.0:
            ilon_check=1
        if minlon>-130 and maxlon<-110.0:
            ilon_check=1
        if minlon<-110 and maxlon>-110.0:
            ilon_check=1
        if ilon_check==1 and ilat_check==1:
            nc = Dataset(file)
            sst = nc.variables['sea_surface_temperature'][:] #:,2500:3250,2500:3500]
            nc.close()
            print(sst.shape,lat2.shape,lon2.shape)
            break
# Out:
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604001000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 0 10
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 56.95008 17.84746
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604002000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 0 20
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 89.99493 49.77807
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604003000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 0 30
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 88.22691 46.665707
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604004000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 0 40
# (1, 5392, 3200) (5408, 3200) (5408, 3200)
# 53.362953 14.201776
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604005000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 0 50
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 18.686983 -20.032652
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604010000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 1 0
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -15.470754 -54.52336
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604011000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 1 10
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -47.494965 -89.24697
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604012000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 1 20
# (1, 5392, 3200) (5408, 3200) (5408, 3200)
# -48.789433 -89.996666
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604013000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 1 30
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -16.957441 -55.974426
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604014000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 1 40
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 17.157286 -21.474798
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604015000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 1 50
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 51.720745 12.781191
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604020000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 2 0
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 86.58244 45.309727
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604021000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 2 10
# (1, 5392, 3200) (5408, 3200) (5408, 3200)
# 89.99912 50.9926
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604022000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 2 20
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 58.49105 19.255484
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604023000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 2 30
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 23.876335 -14.856052
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604024000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 2 40
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -10.405315 -49.319458
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604025000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 2 50
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -42.98426 -84.02649
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604030000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 3 0
# (1, 5392, 3200) (5408, 3200) (5408, 3200)
# -53.030083 -89.99658
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604031000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 3 10
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -21.9661 -61.187958
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604032000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 3 20
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 11.979556 -26.653976
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604033000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 3 30
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 46.50412 7.6849813
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604034000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 3 40
# (1, 5392, 3200) (5408, 3200) (5408, 3200)
# 81.44141 40.679897
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604035000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 3 50
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 89.99787 55.155315
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604040000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 4 0
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 63.726902 24.262217
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604041000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 4 10
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 29.066416 -9.6833515
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604042000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 4 20
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -5.310101 -44.12983
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604043000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 4 30
# (1, 5392, 3200) (5408, 3200) (5408, 3200)
# -38.3352 -78.91086
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604044000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 4 40
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -56.972733 -89.99768
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604045000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 4 50
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -26.923674 -66.40518
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604050000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 5 0
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 6.8114047 -31.832937
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604051000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 5 10
# (1, 5392, 3200) (5408, 3200) (5408, 3200)
# 41.404587 2.5598156
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604052000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 5 20
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 76.19412 36.041916
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604053000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 5 30
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 89.99503 58.98352
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604054000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 5 40
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 68.96962 29.223063
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604055000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 5 50
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 34.260044 -4.515478
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604060000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 6 0
# (1, 5392, 3200) (5408, 3200) (5408, 3200)
# -0.18323317 -39.055656
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604061000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 6 10
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -33.64619 -73.687004
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604062000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 6 20
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -60.50667 -89.99705
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604063000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 6 30
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -31.816965 -71.62852
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604064000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 6 40
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 1.6537234 -37.010525
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604065000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 6 50
# (1, 5392, 3200) (5408, 3200) (5408, 3200)
# 36.211388 -2.5886045
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604070000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 7 0
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 70.94408 31.1486
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604071000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 7 10
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 89.996475 60.353527
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604072000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 7 20
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 74.21956 34.117596
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604073000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 7 30
# (1, 5392, 3200) (5408, 3200) (5408, 3200)
# 39.45751 0.54376894
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604074000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 7 40
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 4.8708496 -33.873013
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604075000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 7 50
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -28.776106 -68.45762
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604080000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 8 0
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -58.367313 -89.99651
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604081000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 8 10
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# -36.632164 -76.8583
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604082000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 8 20
# (1, 5392, 3200) (5408, 3200) (5408, 3200)
# -3.383207 -42.188263
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604083000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 8 30
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 31.008568 -7.6529007
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604084000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 8 40
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 65.69451 26.208555
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604085000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 8 50
# (1, 5392, 3200) (5392, 3200) (5392, 3200)
# 89.99706 56.692284
# https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L2P/VIIRS_NPP/OSPO/v2.41/2018/155/20180604090000-OSPO-L2P_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 155 9 0
# (1, 5392, 3200) (5408, 3200) (5408, 3200)
# 79.47208 38.83317

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
#print(lon2[lon2>0].count())
#print(lon2[lon2<0].count())
print(sst.shape,lon2.shape,lat2.shape)
#if minlon<-110.0 and minlon
#25.03 39.99 -129.97 -110.01
#plt.scatter(lon,lat)
#plt.show()


print('drawing map....') # "Drawing map... ",
m = Basemap(projection='cyl', llcrnrlat=minlat, urcrnrlat=maxlat,\
               llcrnrlon=minlon, urcrnrlon=maxlon, resolution='l')
m.drawcoastlines()
m.drawmapboundary(fill_color='coral') 
#m.scatter(xlist, ylist, 20, c=confidence, cmap=p.cm.hot, marker='o', edgecolors='none', zorder=10)
#m.imshow(sst)
print('done') # "done !"
# Out:
# (1, 5408, 3200) (5408, 3200) (5408, 3200)
# drawing map....
# done
# C:\Users\gentemann\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py:1708: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# C:\Users\gentemann\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py:1711: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:

# %%
#import numpy as np
#from pyresample import image, geometry
#area_def = geometry.AreaDefinition('areaD', 'Europe (3km, HRV, VTC)', 'areaD',
#...                                {'a': '6378144.0', 'b': '6356759.0',
#...                                 'lat_0': '50.00', 'lat_ts': '50.00',
#...                                 'lon_0': '8.00', 'proj': 'stere'},
#...                                800, 800,
#...                                [-1370912.72, -909968.64,
#...                                 1029087.28, 1490031.36])
#swath_def = geometry.SwathDefinition(lons=lon2, lats=lat2)
#swath_con = image.ImageContainerNearest(sst, swath_def, radius_of_influence=5000)
#area_con = swath_con.resample(area_def)
#result = area_con.image_data

# %%
from palettable import colorbrewer
from copy import copy
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.mlab as mlab
palette = copy(plt.cm.jet)
palette.set_over('r', 1.0)
palette.set_under('g', 1.0)
palette.set_bad(alpha = 0.0)
#fig = plt.figure(figsize=(6, 5.4))
# plot using 'continuous' color map
print(sst.shape)
fig, ax = plt.subplots()
im = ax.imshow(sst[0,:,:].T-273.15, interpolation='bilinear',cmap=palette,norm=colors.Normalize(vmin=10, vmax=17.0),aspect='auto',origin='lower')
# We want to show all ticks...
ax.set_xticks(lon2)
ax.set_yticks(lat2)
# ... and label them with the respective list entries
#ax.set_xticklabels(farmers)


#extent=[x0, x1, y0, y1])
#fig.set_title('SST')
#cbar = fig.colorbar(im, extend='both', shrink=0.9, ax=im)
#cbar.set_label('uniform')
#for ticklabel in ax1.xaxis.get_ticklabels():
#   ticklabel.set_visible(False)
plt.show()
# Out:
# (1, 5408, 3200)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-ef49141e6dec> in <module>()
#      14 im = ax.imshow(sst[0,:,:].T-273.15, interpolation='bilinear',cmap=palette,norm=colors.Normalize(vmin=10, vmax=17.0),aspect='auto',origin='lower')
#      15 # We want to show all ticks...
# ---> 16 ax.set_xticks(lon2)
#      17 ax.set_yticks(lat2)
#      18 # ... and label them with the respective list entries
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_xticks(self, ticks, minor)
#    3206             Default is ``False``.
#    3207         """
# -> 3208         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    3209         self.stale = True
#    3210         return ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in set_ticks(self, ticks, minor)
#    1680             xleft, xright = self.get_view_interval()
#    1681             if xright > xleft:
# -> 1682                 self.set_view_interval(min(ticks), max(ticks))
#    1683             else:
#    1684                 self.set_view_interval(max(ticks), min(ticks))
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
        if inew_data==1:
            sst_new = ma.copy(sst)
            inew_data = 0
        if cnt<5:
            continue
        print(ic,cnt,file)
        mask = sst_new < -10
        sst_new[mask] = sst[mask]
     
if itotal_proc>0:
    lat, lon = np.meshgrid(lat, lon)

    mask = (sst_new < -10)
    sst_new[mask]=-9999.
    sst_new2 = sst_new[0,:,:]
    sstx = ma.masked_values (sst_new2, -9999.)
    print(lon.shape,lat.shape,sstx.shape)
    sst3x = np.flip(sstx, 1)
    sst4x = np.flip(sst3x, 0)
    sst5x = ma.swapaxes(sst4x,0,1)
    print(lon.shape,lat.shape,sst5x.shape)

    pixels = 1024 * 10
    cmap = colorbrewer.get_map('Spectral', 'diverging', 11, reverse=True).mpl_colormap

    fig, ax = gearth_fig(llcrnrlon=lon.min(),
                                     llcrnrlat=lat.min(),
                                     urcrnrlon=lon.max(),
                                     urcrnrlat=lat.max(),
                                     pixels=pixels)
    cs = ax.pcolormesh(lon, lat, sst5x - 273.15, cmap=cmap, vmin = 10, vmax = 17)
    ax.set_axis_off()
    fig.savefig(filename_png, transparent=False, format='png')
    print('done')        
    print(lat[1,1],lat[1,-1],lon[1,1],lon[-1,1])
    make_kml(llcrnrlon=lon[1,1], llcrnrlat=lat[1,1],
             urcrnrlon=lon[-1,1], urcrnrlat=lat[1,-1],
             figs= [filename_png], colorbar='legend.png',
             kmzfile=filename_kmz, name='VIIRS Sea Surface Temperature')
    np.save(filename_viirs_proc, proc_save)
    sst_new.dump(filename_viirs_sst)

fig = plt.figure(figsize=(1.0, 4.0), facecolor=None, frameon=False)
ax = fig.add_axes([0.0, 0.05, 0.2, 0.9])
cb = fig.colorbar(cs, cax=ax)
cb.set_label('SST [C]', rotation=-90, color='k', labelpad=20)
fig.savefig('legend.png', transparent=False, format='png')  # Change transparent to True if your colorbar is not on space :)

# %%
#now just do todays data
from os.path import exists

filename_png = 'F:/data/cruise_data/saildrone/baja-2018/today_viirs_sst.png'
filename_kmz = 'F:/data/cruise_data/saildrone/baja-2018/todat_viirs_sst.kmz'
inew_data=1

for incr_day in range(-1,1):
    d = datetime.today() + timedelta(days=incr_day)
    day_of_year = d.timetuple().tm_yday

    url = 'https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L3U/VIIRS_NPP/OSPO/v2.41/' \
            + str(d.year) + '/' + str(day_of_year).zfill(3) + '/'
    ext = 'nc'

    filenames=listFD(url, ext)
    ilen=len(filenames)
    for ic in range(1,ilen):
        file = filenames[ic]
        
        #save which files have been processed
        idyj=int(file[101:104])
        ihr=int(file[113:115])
        imin=int(file[115:117])
            
        nc = Dataset(file)
        sst = nc.variables['sea_surface_temperature'][:,2500:3250,2500:3500]
        sst = np.flip(sst, 2)
        cnt = ma.count(sst)
        lat = nc.variables['lat'][2500:3250]
        lat = np.flip(lat, 0)
        lon = nc.variables['lon'][2500:3500]
        nc.close()
        if inew_data==1:
            sst_new = ma.copy(sst)
            inew_data = 0
        if cnt<5:
            continue
        print(ic,cnt,file)
        mask = sst_new < -10
        sst_new[mask] = sst[mask]
        
    lat, lon = np.meshgrid(lat, lon)
    mask = (sst_new < -10)
    sst_new[mask]=-9999.
    sst_new2 = sst_new[0,:,:]
    sstx = ma.masked_values (sst_new2, -9999.)
    print(lon.shape,lat.shape,sstx.shape)
    sst3x = np.flip(sstx, 1)
    sst4x = np.flip(sst3x, 0)
    sst5x = ma.swapaxes(sst4x,0,1)
    print(lon.shape,lat.shape,sst5x.shape)

    pixels = 1024 * 10
    cmap = colorbrewer.get_map('Spectral', 'diverging', 11, reverse=True).mpl_colormap

    fig, ax = gearth_fig(llcrnrlon=lon.min(),
                                     llcrnrlat=lat.min(),
                                     urcrnrlon=lon.max(),
                                     urcrnrlat=lat.max(),
                                     pixels=pixels)
    cs = ax.pcolormesh(lon, lat, sst5x - 273.15, cmap=cmap, vmin = 10, vmax = 17)
    ax.set_axis_off()
    fig.savefig(filename_png, transparent=False, format='png')
    print('done')        
    print(lat[1,1],lat[1,-1],lon[1,1],lon[-1,1])
    make_kml(llcrnrlon=lon[1,1], llcrnrlat=lat[1,1],
             urcrnrlon=lon[-1,1], urcrnrlat=lat[1,-1],
             figs= [filename_png], colorbar='legend.png',
             kmzfile=filename_kmz, name='VIIRS Sea Surface Temperature')

fig = plt.figure(figsize=(1.0, 4.0), facecolor=None, frameon=False)
ax = fig.add_axes([0.0, 0.05, 0.2, 0.9])
cb = fig.colorbar(cs, cax=ax)
cb.set_label('SST [C]', rotation=-90, color='k', labelpad=20)
fig.savefig('legend.png', transparent=False, format='png')  # Change transparent to True if your colorbar is not on space :)
# Out:
# 57 94954 https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L3U/VIIRS_NPP/OSPO/v2.41/2018/154/20180603093000-OSPO-L3U_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 67 29261 https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L3U/VIIRS_NPP/OSPO/v2.41/2018/154/20180603111000-OSPO-L3U_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 124 37693 https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L3U/VIIRS_NPP/OSPO/v2.41/2018/154/20180603204000-OSPO-L3U_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 125 45759 https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L3U/VIIRS_NPP/OSPO/v2.41/2018/154/20180603205000-OSPO-L3U_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 134 257 https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L3U/VIIRS_NPP/OSPO/v2.41/2018/154/20180603222000-OSPO-L3U_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc
# 135 14603 https://opendap.jpl.nasa.gov/opendap/OceanTemperature/ghrsst/data/GDS2/L3U/VIIRS_NPP/OSPO/v2.41/2018/154/20180603223000-OSPO-L3U_GHRSST-SSTsubskin-VIIRS_NPP-ACSPO_V2.41-v02.0-fv01.0.nc

# %%
pixels = 1024 * 10
cmap = colorbrewer.get_map('Spectral', 'diverging', 11, reverse=True).mpl_colormap
fig, ax = gearth_fig(llcrnrlon=lon.min(),
                                     llcrnrlat=lat.min(),
                                     urcrnrlon=lon.max(),
                                     urcrnrlat=lat.max(),
                                     pixels=pixels)
cs = ax.pcolormesh(lon, lat, sst5x - 273.15, cmap=cmap, vmin = 10, vmax = 17)
ax.set_axis_off()
fig.show()
# Out:
# C:\Users\gentemann\Anaconda3\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
from copy import copy
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.mlab as mlab
print(sst5x.shape)
print(sst4x.shape)
print(sst3x.shape)
palette = copy(plt.cm.jet)
palette.set_over('r', 1.0)
palette.set_under('g', 1.0)
palette.set_bad(alpha = 0.0)
fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(6, 5.4))
# plot using 'continuous' color map
im = ax1.imshow(sst5x - 273.15, interpolation='bilinear',
#im = ax1.imshow(sst4x[540:560,280:289] - 273.15, interpolation='bilinear',
                cmap=palette,
                norm=colors.Normalize(vmin=10.0, vmax=17.0),
                aspect='auto',
                origin='lower')
                #extent=[x0, x1, y0, y1])
ax1.set_title('sst')

plt.show()
print(lon[283,546],lat[283,546])
# Out:
# (1000, 750)
# (750, 1000)
# (750, 1000)
# -124.33 35.93
