# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
adir='F:/data/clim_data/icoads/2010s_subset/*.nc'
ds=xr.open_mfdataset(adir,combine='nested',concat_dim='obs')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (obs: 160699)
# Coordinates:
#     time     (obs) object dask.array<chunksize=(40907,), meta=np.ndarray>
#     lat      (obs) float32 dask.array<chunksize=(40907,), meta=np.ndarray>
#     lon      (obs) float32 dask.array<chunksize=(40907,), meta=np.ndarray>
# Dimensions without coordinates: obs
# Data variables:
#     II       (obs) float32 dask.array<chunksize=(40907,), meta=np.ndarray>
#     AT       (obs) float32 dask.array<chunksize=(40907,), meta=np.ndarray>
#     SI       (obs) float32 dask.array<chunksize=(40907,), meta=np.ndarray>
#     SST      (obs) float32 dask.array<chunksize=(40907,), meta=np.ndarray>
#     PT       (obs) float32 dask.array<chunksize=(40907,), meta=np.ndarray>
#     DUPS     (obs) float32 dask.array<chunksize=(40907,), meta=np.ndarray>
#     DUPC     (obs) float32 dask.array<chunksize=(40907,), meta=np.ndarray>
#     ANC      (obs) float32 dask.array<chunksize=(40907,), meta=np.ndarray>
# ...

# %%
plt.plot(ds.lon,ds.lat,marker='.')

# %%
ds.SST.plot()
