# %%
from netCDF4 import Dataset  # http://code.google.com/p/netcdf4-python/
import os
####################you will need to change some paths here!#####################
filename_nc='F:/data/cruise_data/saildrone/baja-2018/saildrone-gen_4-baja_2018-EP-sd1002-ALL-1_min-v1.nc'
#################################################################################
import datetime as dt
import xarray as xr
from datetime import datetime
import pandas
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

dsx = xr.open_dataset(filename_nc)
#dataset.to_netcdf(filename_out_nc)
#print(dsx)

# %%
lats=dsx.LAT[0,:].values
lons=dsx.LON[0,:].values
skin=dsx.TEMP_IR_MEAN[0,:].values
bulk=dsx.TEMP_CTD_MEAN[0,:].values
bulk2=dsx.TEMP_O2_MEAN[0,:].values
wnd=(dsx.VWND_MEAN[0,:].values**2+dsx.UWND_MEAN[0,:].values**2)**.5
dif=bulk-bulk2

# %%
fig, ax = plt.subplots(2)
ax[0].plot(wnd,bulk-bulk2,'.')
ax[1].plot(bulk,bulk-bulk2,'.')

# %%
import pandas as pd
import numpy as np
t=dsx.TIME[0,:].values
tt=pd.to_datetime(t)
lmt = tt.minute/60+tt.hour + 24.*lons/360.
lmt2=lmt.values
for i in range(0,lmt2.shape[0]):
    if lmt2[i]>=24:
        lmt2[i]=lmt2[i]-24
    if lmt2[i]<0:
        lmt2[i]=lmt2[i]+24
        
#over = lmt > 24
#print(len(over))

# %%
fig, ax = plt.subplots(2)
ax[0].plot(lmt2,bulk-bulk2,'.')
ax[1].plot(bulk,skin-bulk,'.')
