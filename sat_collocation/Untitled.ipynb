# %%
import xarray as xr
filename = 'F:/data/sat_data/ccmp/v02.0/Y2018/M04/CCMP_RT_Wind_Analysis_20180411_V02.0_L3.0_RSS.nc'
ds = xr.open_dataset(filename)
ds.close()
print(ds)
ds.uwnd[1,:,:].plot()  #plot the 06:00 map
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 628, longitude: 1440, time: 4)
# Coordinates:
#   * longitude  (longitude) float32 0.125 0.375 0.625 ... 359.375 359.625 359.875
#   * latitude   (latitude) float32 -78.375 -78.125 -77.875 ... 78.125 78.375
#   * time       (time) datetime64[ns] 2018-04-11 ... 2018-04-11T18:00:00
# Data variables:
#     uwnd       (time, latitude, longitude) float32 ...
#     vwnd       (time, latitude, longitude) float32 ...
#     nobs       (time, latitude, longitude) float32 ...
# Attributes:
#     contact:                    Remote Sensing Systems, support@remss.com
#     Conventions:                CF-1.6
#     data_structure:             grid
#     title:                      RSS CCMP_RT V2.1 derived surface winds (Level...
#     history:                    20180426T175522ZZ - netCDF generated from ori...
#     description:                RSS VAM 6-hour analyses starting from the NCE...
# ...
